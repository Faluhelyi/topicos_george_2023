# %%
import pandas as pd
import numpy as np


df = pd.read_excel('sample_whr.xlsx')

# %%
for col in df.columns[:-1]:
    df.loc[df.sample(frac=0.03571428571428571).index, col] = np.nan

# %%
df
# Out:
#        Score  Logged GDP per capita  Social support  Healthy life expectancy
# 0   0.665899               0.686644        0.770998                 0.666364  \
# 1   0.752674               0.747934        0.854331                 0.728929
# 2   0.684905               0.776334        0.769832                 0.761937
# 3   0.649801               0.698795        0.855071                 0.604662
# 4   0.716982               0.580835        0.644740                 0.546289
# 5   0.720733               0.756428        0.920326                 0.554243
# 6   0.905117               0.919142        0.903159                 0.829907
# 7   0.666117               0.647629        0.803650                 0.534722
# 8   0.646522               0.593143        0.820305                 0.585244
# 9   0.725661               0.855840        0.783704                 0.555147
# 10  0.779604               0.735304        0.891882                 0.620196
# ...
